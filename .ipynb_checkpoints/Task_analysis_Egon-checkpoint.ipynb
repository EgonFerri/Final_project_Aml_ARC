# %%
from google.colab import output
output.eval_js('new Audio("https://upload.wikimedia.org/wikipedia/commons/0/05/Beep-09.ogg").play()')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-40-c5b7e396cfc9> in <module>
# ----> 1 from google.colab import output
#       2 output.eval_js('new Audio("https://upload.wikimedia.org/wikipedia/commons/0/05/Beep-09.ogg").play()')
#
# ModuleNotFoundError: No module named 'google'

# %% [markdown]
# # Load files

# %%
# !pip install -q -U PyDrive # to get access to files

# Import PyDrive and associated libraries.
# This only needs to be done once per notebook.
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Authenticate and create the PyDrive client.
# This only needs to be done once per notebook.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

file_id = '1joDmxc9dbVHB0XuJrLtY5nlOX339dd5R'
downloaded = drive.CreateFile({'id': file_id})
downloaded.GetContentFile('Final_data.zip')
# !unzip -q Final_data.zip
# !ls Final_data
# Out:
# replace Final_data/Final_data/evaluation/00576224.json? [y]es, [n]o, [A]ll, [N]one, [r]ename: N
# Final_data

# %%
import numpy as np              #numpy library is used to work with multidimensional array.
import pandas as pd             #panda used for data manipulation and analysis.                
import os                       #os library is used for loading file to use in the program
import json                     #json library parses json into a string or dict, and convert string or dict to json file.
from pathlib import Path        #support path
import matplotlib.pyplot as plt #support ploting a figure
from matplotlib import colors   #colors support converting number or argument into colors
from tqdm.notebook import tqdm_notebook as tqdm
import pickle
from torch import FloatTensor, LongTensor
import torch
from torch.nn import CrossEntropyLoss
from torch.autograd import Variable
from torch.optim import Adam
import torch.nn as nn
import torch.nn.functional as F

is_cuda = torch.cuda.is_available()
if is_cuda:
    device = torch.device("cuda")
else:
    device = torch.device("cpu")

import sys
sys.path.insert(0,'src')

from importlib import reload  
from generators import *
from models import *
from solvers import *
from utils import *

path = 'results/'

# %%
import solvers
solvers = reload(solvers)
from solvers import *

# %%
from importlib import reload  
import models
models = reload(models)
from models import *

# %%
dimension_explained('data', 'train')
dimension_explained('data','eval')
dimension_explained('data','test')
# Out:
# ------------ train  shapes ------------
# t1 all inputs are equal:  210 of which:
# t1_1 also output equal:  134
# t1_2 output smaller but fixed:  43
# t1_3 output bigger but fixed:  19
# t1_4 output size depends on input:  14
# t2 input different:  190 of which:
# t2_1 output equal to input:  128
# t2_2 output smaller:  50
# t2_3 output bigger:  12
# ------------ eval  shapes ------------
# t1 all inputs are equal:  157 of which:
# t1_1 also output equal:  92
# t1_2 output smaller but fixed:  32
# t1_3 output bigger but fixed:  20
# t1_4 output size depends on input:  13
# t2 input different:  243 of which:
# t2_1 output equal to input:  178
# t2_2 output smaller:  51
# t2_3 output bigger:  14
# ------------ test  shapes ------------
# t1 all inputs are equal:  41 of which:
# t1_1 also output equal:  23
# t1_2 output smaller but fixed:  8
# t1_3 output bigger but fixed:  7
# t1_4 output size depends on input:  3
# t2 input different:  59 of which:
# t2_1 output equal to input:  42
# t2_2 output smaller:  15
# t2_3 output bigger:  2

# %% [markdown]
# # All 7 task

# %%
# TASK 1 - Same dimension: Mirror right and down
def gener_one():
    skeleton=np.random.randint(2,size=(3,4))
    color=np.random.randint(1, 10)
    inp=np.where(skeleton==0, 0, color)
    flip_right=np.concatenate((inp,np.flip(inp, axis=1)), axis=1)
    out=np.concatenate((flip_right,np.flip(flip_right, axis=0)), axis=0)
    return(inp, out)

# %%
# TASK 2 - Same dimension: Concatenate and flip central row
def gener_two():
    inp=np.random.randint(1,10,size=(2,2))
    flip=np.flip(inp, axis=1)
    conc1=np.concatenate((inp, inp, inp), axis=1)
    conc2=np.concatenate((flip, flip, flip), axis=1)
    out=np.concatenate((conc1, conc2, conc1), axis=0)
    return(inp, out)

# %%
# TASK 3 - Same dimension: Pattern filler
def gener_three():
    a = np.random.randint(2, 10, (8, 8))
    a = np.where(a==4, 1, a)
    m = np.tril(a) + np.tril(a, -1).T
    m = np.concatenate((m, np.flip(m, axis=0)), axis=0)
    out= np.concatenate((m, np.flip(m)), axis=1)
    inp = out.copy()

    p1=np.random.randint(1, 13)
    p2=np.random.randint(p1+2, p1+5)
    p3=np.random.randint(1, 13)
    p4=np.random.randint(p3+2, p3+5)

    inp[p1:p2, p3:p4]=4

    p1=np.random.randint(1, 13)
    p2=np.random.randint(p1+2, p1+5)
    p3=np.random.randint(1, 13)
    p4=np.random.randint(p3+2, p3+5)

    inp[p1:p2, p3:p4]=4 
    
    return(inp, out)

# %%
# TASK 4 - Different dimension: Denoise
def gener_four():
    dim1=np.random.randint(10,15)
    dim2=np.random.randint(13,18)
    out=np.zeros((dim1,dim2))
    col=np.random.choice([2,3,5])
    colno=np.random.choice([1,4,8])
    nsquare=np.random.randint(3,5)
    nnoise=np.random.randint(10,20)
    for sq in range(0,nsquare):
        p1=np.random.randint(0, dim1-1)
        p2=np.random.randint(p1+2, p1+8)
        p3=np.random.randint(0, dim2-1)
        p4=np.random.randint(p3+2, p3+8)

        out[p1:p2, p3:p4]=col

    inp=out.copy()

    for noise in range(0,nnoise):
        p1=np.random.randint(0, dim1)
        p2=np.random.randint(0, dim2)

        inp[p1,p2]=colno
    return(inp, out)

# %%
# TASK 5 - Different dimension: 2 squares
def gener_five():
    dim1=np.random.randint(5,11)
    dim2=np.random.randint(5,11)
    out=np.zeros((dim1,dim2))
    inp=out.copy()
    col=np.random.randint(1,10)
    col2=np.random.randint(1,10)
    nsquare=np.random.randint(1,3)
    
    flippoints=np.random.randint(1,3)
    
    while col2==col:
        col2=np.random.randint(1,10)

    if nsquare==1:
        p1=np.random.randint(0, dim1-2)
        p2=np.random.randint(p1+2,dim1)
        p3=np.random.randint(0, dim2-2)
        p4=np.random.randint(p3+2,dim2)

        out[p1:p2+1, p3:p4+1]=col
        inp[p1, p3]=col
        inp[p2, p4]=col
    if nsquare==2:
        if dim1>dim2:
            p1= np.random.randint(0, dim1-3)
            p2= np.random.randint(p1+1, dim1-2)
            p11= np.random.randint(p2+1, dim1-1)
            p22= np.random.randint(p11+1, dim1)
            p3= np.random.randint(0, dim2-3)
            p4= np.random.randint(p3+1, dim2)
            p33= np.random.randint(0, dim2-3)
            p44= np.random.randint(p33+1, dim2)

            out[p1:p2+1, p3:p4+1]=col            
            out[p11:p22+1, p33:p44+1]=col2
            
            if flippoints==1:
                inp[p1, p3]=col
                inp[p2, p4]=col            
                inp[p22, p33]=col2
                inp[p11, p44]=col2
            else:
                inp[p2, p3]=col
                inp[p1, p4]=col            
                inp[p11, p33]=col2
                inp[p22, p44]=col2
                
        else:
            p1= np.random.randint(0, dim1-3)
            p2= np.random.randint(p1+1, dim1)
            p11= np.random.randint(0, dim1-3)
            p22= np.random.randint(p11+1, dim1)
            p3= np.random.randint(0, dim2-3)
            p4= np.random.randint(p3+1, dim2-2)
            p33= np.random.randint(p4+1, dim2-1)
            p44= np.random.randint(p33+1, dim2)

            out[p1:p2+1, p3:p4+1]=col            
            out[p11:p22+1, p33:p44+1]=col2
            
            if flippoints==1:
                inp[p1, p3]=col
                inp[p2, p4]=col            
                inp[p22, p33]=col2
                inp[p11, p44]=col2
            else:
                inp[p2, p3]=col
                inp[p1, p4]=col            
                inp[p11, p33]=col2
                inp[p22, p44]=col2
    return(inp, out)

# %%
# TASK 6 - Different dimension: smallest squares
def gener_six():
    dim1=np.random.randint(8,21)
    dim2=np.random.randint(8,21)
    inp=np.zeros((dim1,dim2))
    nsquare=np.random.randint(2,6)
    colors=np.random.choice(range(1,10),5, replace=False)
    sqs=[]
    for i in range(0, nsquare):
        p1=np.random.randint(1, dim1-3)
        p2=np.random.randint(p1+1,dim1-1)
        p3=np.random.randint(1, dim2-3)
        p4=np.random.randint(p3+1,dim2-1)
        sqs.append([((p2-p1)*(p4-p3)), p1,p2,p3,p4, colors[i]])
        
    sortt=sorted(sqs, reverse=True)
    for sq in sortt:
        _,p1,p2,p3,p4,col=sq
        inp[p1:p2+1, p3:p4+1]=col
    _,p1,p2,p3,p4,col=sortt[-1]
    
    out=np.ones((p2-p1,p4-p3))*col
    
    
    return(inp, out)

# %%
# TASK 7 - Different dimension: inverter
def gener_seven():
    dim1=np.random.randint(18,26)
    dim2=np.random.randint(18,26)
    colors=np.random.choice(range(1,10),2, replace=False)
    inp=np.zeros((dim1,dim2))
    
    nnoise=np.random.randint(15,50)
    for noise in range(0,nnoise):
        p1=np.random.randint(0, dim1)
        p2=np.random.randint(0, dim2)

        inp[p1,p2]=colors[0]
        
    
    
    skel=np.random.randint(2,size=(3,3))
    out=skel*colors[0]
    topaste=np.kron(skel, np.ones((4,4)))*colors[1]
    
    p1=np.random.randint(0, dim1-12)
    p2=np.random.randint(0,dim2-12)
    
    inp[p1:p1+12, p2:p2+12]=topaste
    
    return(inp, out)

# %% [markdown]
# # Task 1

# %%
task=task_builder(gener_one, 5, 2)
plot_task(task)

# %% [markdown]
# ## FCN

# %%
data=[task_builder(gener_one, 10000, 100)]

# %%
# Training
FullyCon_result_T1, FullyCon__predictions_T1, FullyCon_wrong_pred_T1 = evaluate_metrics(TaskSolver(), 
                                                                                        data, 
                                                                                        FullyCon, CrossEntropyLoss, 
                                                                                        n_epoch=5, device=device,
                                                                                        lr = 0.1, verbose=True, attention = False)

save_results(path, [FullyCon_result_T1, FullyCon__predictions_T1, FullyCon_wrong_pred_T1], 
             ['FullyCon_result_T1', 'FullyCon__predictions_T1', 'FullyCon_wrong_pred_T1'])


plot_metrics(load_results(path, 'FullyCon_result_T1'))

output.eval_js('new Audio("https://upload.wikimedia.org/wikipedia/commons/0/05/Beep-09.ogg").play()')
# Out:
#  20%|████████████████▊                                                                   | 1/5 [00:28<01:53, 28.25s/it]
# Epoch: [1/5]
# Train loss is: 0.010267382939585989
# Validation loss is: 0.006293194060990572
# Train accuracy is: 90.13 %
# Train accuracy for pixels is: 99.768125 %
# Validation accuracy is: 93.0 %
# Validation accuracy for pixels is: 99.8125 %
#  40%|█████████████████████████████████▌                                                  | 2/5 [00:55<01:24, 28.03s/it]
# Epoch: [2/5]
# Train loss is: 0.0008153341847781418
# Validation loss is: 1.7898132869746954e-05
# Train accuracy is: 98.9 %
# Train accuracy for pixels is: 99.97708333333334 %
# Validation accuracy is: 100.0 %
# Validation accuracy for pixels is: 100.0 %
#  60%|██████████████████████████████████████████████████▍                                 | 3/5 [01:23<00:55, 27.82s/it]
# Epoch: [3/5]
# Train loss is: 1.4391663550688395e-05
# Validation loss is: 1.845260466870613e-08
# Train accuracy is: 99.97 %
# Train accuracy for pixels is: 99.999375 %
# Validation accuracy is: 100.0 %
# Validation accuracy for pixels is: 100.0 %
#  80%|███████████████████████████████████████████████████████████████████▏                | 4/5 [01:50<00:27, 27.83s/it]
# Epoch: [4/5]
# Train loss is: 1.1163453300877536e-09
# Validation loss is: 2.9553969516094013e-09
# Train accuracy is: 100.0 %
# Train accuracy for pixels is: 100.0 %
# Validation accuracy is: 100.0 %
# Validation accuracy for pixels is: 100.0 %
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [02:18<00:00, 27.70s/it]
# Epoch: [5/5]
# Train loss is: 1.6706744869259937e-06
# Validation loss is: 2.235174210163393e-09
# Train accuracy is: 100.0 %
# Train accuracy for pixels is: 100.0 %
# Validation accuracy is: 100.0 %
# Validation accuracy for pixels is: 100.0 %
# C:\Users\Egon\Anaconda3\envs\pytorch\lib\site-packages\torch\storage.py:34: FutureWarning: pickle support for Storage will be removed in 1.5. Use `torch.save` instead
#   warnings.warn("pickle support for Storage will be removed in 1.5. Use `torch.save` instead", FutureWarning)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-f95feadc45dc> in <module>
#      12 plot_metrics(load_results(path, 'FullyCon_result_T1'))
#      13
# ---> 14 output.eval_js('new Audio("https://upload.wikimedia.org/wikipedia/commons/0/05/Beep-09.ogg").play()')
#
# NameError: name 'output' is not defined

# %%
compare_plots(load_results(path, 'FullyCon__predictions_T1'), n = 5)

# %%
len(load_results(path,'FullyCon_wrong_pred_T1')) # all results are correct
# Out:
# 0

# %% [markdown]
# ## LSTM

# %%
# Training with attention
LSTM_result_T1, LSTM_predictions_T1, LSTM_wrong_pred_T1 = evaluate_metrics(TaskSolver(), 
                                                                            data, 
                                                                            LSTM, CrossEntropyLoss, 
                                                                            attention = 'yes',
                                                                            n_epoch=5, device=device,
                                                                            lr = 0.1, verbose=True)

save_results(path, [LSTM_result_T1, LSTM_predictions_T1, LSTM_wrong_pred_T1], 
             ['LSTM_result_T1', 'LSTM_predictions_T1', 'LSTM_wrong_pred_T1'])

plot_metrics(load_results(path, 'LSTM_result_T1'))

output.eval_js('new Audio("https://upload.wikimedia.org/wikipedia/commons/0/05/Beep-09.ogg").play()')
# Out:
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]src\models.py:187: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#
#  20%|████████████████▊                                                                   | 1/5 [00:56<03:46, 56.64s/it]
# Epoch: [1/5]
# Train loss is: 1.3301656382083893
# Validation loss is: 1.3275130605697631
# Train accuracy is: 0.04 %
# Train accuracy for pixels is: 87.32395833333334 %
# Validation accuracy is: 0.0 %
# Validation accuracy for pixels is: 87.8125 %
#  40%|█████████████████████████████████▌                                                  | 2/5 [01:52<02:49, 56.48s/it]
# Epoch: [2/5]
# Train loss is: 1.2291238290786743
# Validation loss is: 1.2301186692714692
# Train accuracy is: 13.43 %
# Train accuracy for pixels is: 95.34958333333333 %
# Validation accuracy is: 9.0 %
# Validation accuracy for pixels is: 95.45833333333333 %
#  60%|██████████████████████████████████████████████████▍                                 | 3/5 [02:51<01:54, 57.29s/it]
# Epoch: [3/5]
# Train loss is: 1.1556501145482063
# Validation loss is: 1.1558722865581512
# Train accuracy is: 36.12 %
# Train accuracy for pixels is: 98.24791666666667 %
# Validation accuracy is: 32.0 %
# Validation accuracy for pixels is: 98.20833333333333 %
#  80%|███████████████████████████████████████████████████████████████████▏                | 4/5 [03:51<00:57, 57.99s/it]
# Epoch: [4/5]
# Train loss is: 1.1714297979831696
# Validation loss is: 1.1703739726543427
# Train accuracy is: 30.21 %
# Train accuracy for pixels is: 96.78791666666666 %
# Validation accuracy is: 29.0 %
# Validation accuracy for pixels is: 96.83333333333333 %
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [04:52<00:00, 58.47s/it]
# Epoch: [5/5]
# Train loss is: 1.1504628942489623
# Validation loss is: 1.1504519975185394
# Train accuracy is: 30.89 %
# Train accuracy for pixels is: 97.501875 %
# Validation accuracy is: 28.0 %
# Validation accuracy for pixels is: 97.4375 %
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-45-ac300dc77652> in <module>
#       7                                                                             lr = 0.1, verbose=True)
#       8
# ----> 9 save_results(path, [LSTM_result_T1, LSTM_predictions_T1, LSTM_wrong_pred_T1],
#      10              ['LSTM_result_T1', 'LSTM_predictions_T1', 'LSTM_wrong_pred_T1'])
#      11
#
# ~\Desktop\Universita\ultimosemestre\AML\Final_project_ARC\abstraction-and-reasoning-challenge\src\solvers.py in save_results(path, list_res, list_names)
#     456     :list_names: list of names to give to each output file in list_res
#     457     """
# --> 458     with open(path+list_names[0]+'.pickle', 'wb') as handle:
#     459       pickle.dump(list_res[0], handle, protocol=pickle.HIGHEST_PROTOCOL)
#     460     with open(path+list_names[1]+'.pickle', 'wb') as handle:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/My Drive/scr/results/LSTM_result_T1.pickle'

# %%
correct = find_correct_pred(load_results(path, 'LSTM_predictions_T1'), 
                            load_results(path, 'LSTM_wrong_pred_T1'))
compare_plots(correct, n = len(correct)) # 5 correct predictions

# %%
compare_plots(load_results(path, 'LSTM_wrong_pred_T1'), n = 5) # 5 wrong predictions

# %%
# Training without attention 
LSTM_no_result_T1, LSTM_no_predictions_T1, LSTM_no_wrong_pred_T1 = evaluate_metrics(TaskSolver(), 
                                                                            data, 
                                                                            LSTM, CrossEntropyLoss, 
                                                                            attention = None,
                                                                            n_epoch=5, device=device,
                                                                            lr = 0.1, verbose=True)

save_results(path, [LSTM_no_result_T1, LSTM_no_predictions_T1, LSTM_no_wrong_pred_T1], 
             ['LSTM_no_result_T1', 'LSTM_no_predictions_T1', 'LSTM_no_wrong_pred_T1'])


plot_metrics(load_results(path, 'LSTM_no_result_T1'))

output.eval_js('new Audio("https://upload.wikimedia.org/wikipedia/commons/0/05/Beep-09.ogg").play()')
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
#  20%|██        | 1/5 [00:42<02:48, 42.19s/it]
# Epoch: [1/5]
# Train loss is: 1.3940496338248254
# Validation loss is: 1.3928398561477662
# Train accuracy is: 0.33 %
# Train accuracy for pixels is: 88.54895833333333 %
# Validation accuracy is: 0.0 %
# Validation accuracy for pixels is: 89.04166666666667 %
#  40%|████      | 2/5 [01:24<02:06, 42.11s/it]
# Epoch: [2/5]
# Train loss is: 1.373323172557354
# Validation loss is: 1.3734434950351715
# Train accuracy is: 5.01 %
# Train accuracy for pixels is: 89.51666666666667 %
# Validation accuracy is: 4.0 %
# Validation accuracy for pixels is: 89.875 %
#  60%|██████    | 3/5 [02:06<01:24, 42.07s/it]
# Epoch: [3/5]
# Train loss is: 1.2740564212799073
# Validation loss is: 1.2693238496780395
# Train accuracy is: 14.52 %
# Train accuracy for pixels is: 93.815 %
# Validation accuracy is: 18.0 %
# Validation accuracy for pixels is: 94.29166666666667 %
#  80%|████████  | 4/5 [02:48<00:42, 42.10s/it]
# Epoch: [4/5]
# Train loss is: 1.2762479894399643
# Validation loss is: 1.2787729346752166
# Train accuracy is: 13.67 %
# Train accuracy for pixels is: 93.06041666666667 %
# Validation accuracy is: 15.0 %
# Validation accuracy for pixels is: 92.95833333333333 %
# 100%|██████████| 5/5 [03:30<00:00, 42.11s/it]
# Epoch: [5/5]
# Train loss is: 1.2178052581071854
# Validation loss is: 1.2167778050899505
# Train accuracy is: 26.7 %
# Train accuracy for pixels is: 97.47083333333333 %
# Validation accuracy is: 26.0 %
# Validation accuracy for pixels is: 97.5625 %
# /usr/local/lib/python3.6/dist-packages/torch/storage.py:34: FutureWarning: pickle support for Storage will be removed in 1.5. Use `torch.save` instead
#   warnings.warn("pickle support for Storage will be removed in 1.5. Use `torch.save` instead", FutureWarning)

# %%
correct = find_correct_pred(load_results(path, 'LSTM_no_predictions_T1'), 
                            load_results(path, 'LSTM_no_wrong_pred_T1'))
compare_plots(correct, n = len(correct)) # 5 correct predictions

# %%
compare_plots(load_results(path, 'LSTM_no_wrong_pred_T1'), n = 5) # 5 wrong predictions

# %% [markdown]
# ## CNN

# %%
# Training with attention
CNN_result_T1, CNN_predictions_T1, CNN_wrong_pred_T1 = evaluate_metrics(TaskSolver(), 
                                                                            data, 
                                                                            CNN, CrossEntropyLoss, 
                                                                            attention = 'yes',
                                                                            n_epoch=5, device=device,
                                                                            lr = 0.1, verbose=True)

save_results(path, [CNN_result_T1, CNN_predictions_T1, CNN_wrong_pred_T1], 
             ['CNN_result_T1', 'CNN_predictions_T1', 'CNN_wrong_pred_T1'])


plot_metrics(load_results(path,'CNN_result_T1'))

output.eval_js('new Audio("https://upload.wikimedia.org/wikipedia/commons/0/05/Beep-09.ogg").play()')
# Out:
#  20%|████████████████▊                                                                   | 1/5 [00:42<02:50, 42.63s/it]
# Epoch: [1/5]
# Train loss is: 0.5926058672629296
# Validation loss is: 0.6180669054389
# Train accuracy is: 0.01 %
# Train accuracy for pixels is: 76.66604166666667 %
# Validation accuracy is: 0.0 %
# Validation accuracy for pixels is: 76.52083333333333 %
#  40%|█████████████████████████████████▌                                                  | 2/5 [01:25<02:07, 42.60s/it]
# Epoch: [2/5]
# Train loss is: 0.5935947257325053
# Validation loss is: 0.6192462456226349
# Train accuracy is: 0.01 %
# Train accuracy for pixels is: 76.661875 %
# Validation accuracy is: 0.0 %
# Validation accuracy for pixels is: 76.5625 %
#  60%|██████████████████████████████████████████████████▍                                 | 3/5 [02:10<01:26, 43.45s/it]
# Epoch: [3/5]
# Train loss is: 0.5935717163361609
# Validation loss is: 0.6192067486047744
# Train accuracy is: 0.01 %
# Train accuracy for pixels is: 76.66395833333333 %
# Validation accuracy is: 0.0 %
# Validation accuracy for pixels is: 76.5625 %
#  80%|███████████████████████████████████████████████████████████████████▏                | 4/5 [02:52<00:43, 43.11s/it]
# Epoch: [4/5]
# Train loss is: 0.5935684581659735
# Validation loss is: 0.6192043060064316
# Train accuracy is: 0.01 %
# Train accuracy for pixels is: 76.66395833333333 %
# Validation accuracy is: 0.0 %
# Validation accuracy for pixels is: 76.5625 %
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [03:36<00:00, 43.35s/it]
# Epoch: [5/5]
# Train loss is: 0.59356801218912
# Validation loss is: 0.619203553199768
# Train accuracy is: 0.01 %
# Train accuracy for pixels is: 76.66375 %
# Validation accuracy is: 0.0 %
# Validation accuracy for pixels is: 76.5625 %
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-05041e8f8e96> in <module>
#      13 plot_metrics(load_results(path,'CNN_result_T1'))
#      14
# ---> 15 output.eval_js('new Audio("https://upload.wikimedia.org/wikipedia/commons/0/05/Beep-09.ogg").play()')
#
# NameError: name 'output' is not defined

# %%
compare_plots(load_results(path, 'CNN_wrong_pred_T1'), n = 5) # 5 wrong predictions

# %%
# Training without attention
CNN_no_result_T1, CNN_no_predictions_T1, CNN_no_wrong_pred_T1 = evaluate_metrics(TaskSolver(), 
                                                                            data, 
                                                                            CNN, CrossEntropyLoss, 
                                                                            attention = None,
                                                                            n_epoch=5, device=device,
                                                                            lr = 0.1, verbose=True)

save_results(path, [CNN_no_result_T1, CNN_no_predictions_T1, CNN_no_wrong_pred_T1], 
             ['CNN_no_result_T1', 'CNN_no_predictions_T1', 'CNN_no_wrong_pred_T1'])


plot_metrics(load_results(path, 'CNN_no_result_T1'))

output.eval_js('new Audio("https://upload.wikimedia.org/wikipedia/commons/0/05/Beep-09.ogg").play()')
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
#  20%|██        | 1/5 [00:28<01:53, 28.42s/it]
# Epoch: [1/5]
# Train loss is: 0.5979649963125586
# Validation loss is: 0.6153196647763253
# Train accuracy is: 0.02 %
# Train accuracy for pixels is: 75.32208333333334 %
# Validation accuracy is: 0.0 %
# Validation accuracy for pixels is: 74.97916666666667 %
#  40%|████      | 2/5 [00:56<01:24, 28.24s/it]
# Epoch: [2/5]
# Train loss is: 0.5987647813685238
# Validation loss is: 0.6166239084303379
# Train accuracy is: 0.02 %
# Train accuracy for pixels is: 75.313125 %
# Validation accuracy is: 0.0 %
# Validation accuracy for pixels is: 75.02083333333333 %
#  60%|██████    | 3/5 [01:23<00:56, 28.03s/it]
# Epoch: [3/5]
# Train loss is: 0.5987650943905115
# Validation loss is: 0.6166117417812348
# Train accuracy is: 0.02 %
# Train accuracy for pixels is: 75.31291666666667 %
# Validation accuracy is: 0.0 %
# Validation accuracy for pixels is: 75.02083333333333 %
#  80%|████████  | 4/5 [01:51<00:27, 27.83s/it]
# Epoch: [4/5]
# Train loss is: 0.598784764983505
# Validation loss is: 0.6166314882040024
# Train accuracy is: 0.02 %
# Train accuracy for pixels is: 75.31354166666667 %
# Validation accuracy is: 0.0 %
# Validation accuracy for pixels is: 75.02083333333333 %
# 100%|██████████| 5/5 [02:18<00:00, 27.75s/it]
# Epoch: [5/5]
# Train loss is: 0.5987837790079414
# Validation loss is: 0.6166308672726154
# Train accuracy is: 0.02 %
# Train accuracy for pixels is: 75.31354166666667 %
# Validation accuracy is: 0.0 %
# Validation accuracy for pixels is: 75.02083333333333 %
# /usr/local/lib/python3.6/dist-packages/torch/storage.py:34: FutureWarning: pickle support for Storage will be removed in 1.5. Use `torch.save` instead
#   warnings.warn("pickle support for Storage will be removed in 1.5. Use `torch.save` instead", FutureWarning)

# %%
compare_plots(load_results(path, 'CNN_no_wrong_pred_T1'), n = 5) # 5 wrong predictions

# %%
CNNB_result_T1, CNNB_predictions_T1, CNNB_wrong_pred_T1 = evaluate_metrics(TaskSolver(), 
                                                                            data, 
                                                                            CNN_big, CrossEntropyLoss, 
                                                                            attention = 'yes',
                                                                            n_epoch=5, device=device,
                                                                            lr = 0.1, verbose=True)

save_results(path, [CNN_result_T1, CNN_predictions_T1, CNN_wrong_pred_T1], 
             ['CNN_result_T1', 'CNN_predictions_T1', 'CNN_wrong_pred_T1'])


plot_metrics(load_results(path,'CNN_result_T1'))
# Out:
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]src\models.py:216: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   out = (x * alpha.unsqueeze(2)).sum(dim=1)
#  20%|████████████████▊                                                                   | 1/5 [00:54<03:38, 54.58s/it]
# Epoch: [1/5]
# Train loss is: 71.59552744571369
# Validation loss is: 76.06093044638634
# Train accuracy is: 0.23 %
# Train accuracy for pixels is: 84.291875 %
# Validation accuracy is: 0.0 %
# Validation accuracy for pixels is: 83.58333333333333 %
#  40%|█████████████████████████████████▌                                                  | 2/5 [01:50<02:44, 54.96s/it]
# Epoch: [2/5]
# Train loss is: 60.13638860815562
# Validation loss is: 67.29392889022827
# Train accuracy is: 0.26 %
# Train accuracy for pixels is: 84.644375 %
# Validation accuracy is: 2.0 %
# Validation accuracy for pixels is: 83.52083333333333 %
#  60%|██████████████████████████████████████████████████▍                                 | 3/5 [02:46<01:50, 55.33s/it]
# Epoch: [3/5]
# Train loss is: 77.77201857340572
# Validation loss is: 80.50957405388355
# Train accuracy is: 0.34 %
# Train accuracy for pixels is: 85.19625 %
# Validation accuracy is: 1.0 %
# Validation accuracy for pixels is: 84.20833333333333 %
#  80%|███████████████████████████████████████████████████████████████████▏                | 4/5 [03:50<00:57, 57.84s/it]
# Epoch: [4/5]
# Train loss is: 64.50623633505714
# Validation loss is: 69.23556694824248
# Train accuracy is: 0.24 %
# Train accuracy for pixels is: 84.41041666666666 %
# Validation accuracy is: 2.0 %
# Validation accuracy for pixels is: 83.9375 %
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [04:44<00:00, 56.94s/it]
# Epoch: [5/5]
# Train loss is: 58.48789595154238
# Validation loss is: 62.92342676401138
# Train accuracy is: 0.27 %
# Train accuracy for pixels is: 85.293125 %
# Validation accuracy is: 1.0 %
# Validation accuracy for pixels is: 84.125 %
# C:\Users\Egon\Anaconda3\envs\pytorch\lib\site-packages\torch\storage.py:34: FutureWarning: pickle support for Storage will be removed in 1.5. Use `torch.save` instead
#   warnings.warn("pickle support for Storage will be removed in 1.5. Use `torch.save` instead", FutureWarning)

# %% [markdown]
# # Task 2

# %%
task=task_builder(gener_two, 5, 2)
plot_task(task)

# %%
data=[task_builder(gener_two, 10000, 100)]

# %% [markdown]
# ## FCN

# %%
# Training
FullyCon_result_T2, FullyCon__predictions_T2, FullyCon_wrong_pred_T2 = evaluate_metrics(TaskSolver(), 
                                                                                        data, 
                                                                                        FullyCon, CrossEntropyLoss, 
                                                                                        n_epoch=5, device=device,
                                                                                        lr = 0.1, verbose=True, attention = False)

save_results(path, [FullyCon_result_T2, FullyCon__predictions_T2, FullyCon_wrong_pred_T2], 
             ['FullyCon_result_T2', 'FullyCon__predictions_T2', 'FullyCon_wrong_pred_T2'])


plot_metrics(load_results(path, 'FullyCon_result_T2'))

output.eval_js('new Audio("https://upload.wikimedia.org/wikipedia/commons/0/05/Beep-09.ogg").play()')
# Out:
#  20%|██        | 1/5 [00:22<01:29, 22.35s/it]
# Epoch: [1/5]
# Train loss is: 1.210540665397275e-05
# Validation loss is: 1.2242926486578653e-05
# Train accuracy is: 100.0 %
# Train accuracy for pixels is: 100.0 %
# Validation accuracy is: 100.0 %
# Validation accuracy for pixels is: 100.0 %
#  40%|████      | 2/5 [00:45<01:07, 22.65s/it]
# Epoch: [2/5]
# Train loss is: 5.4154131726491525e-09
# Validation loss is: 6.887647923115026e-09
# Train accuracy is: 100.0 %
# Train accuracy for pixels is: 100.0 %
# Validation accuracy is: 100.0 %
# Validation accuracy for pixels is: 100.0 %
#  60%|██████    | 3/5 [01:08<00:45, 22.60s/it]
# Epoch: [3/5]
# Train loss is: 0.0
# Validation loss is: 0.0
# Train accuracy is: 100.0 %
# Train accuracy for pixels is: 100.0 %
# Validation accuracy is: 100.0 %
# Validation accuracy for pixels is: 100.0 %
#  80%|████████  | 4/5 [01:30<00:22, 22.57s/it]
# Epoch: [4/5]
# Train loss is: 0.0
# Validation loss is: 0.0
# Train accuracy is: 100.0 %
# Train accuracy for pixels is: 100.0 %
# Validation accuracy is: 100.0 %
# Validation accuracy for pixels is: 100.0 %
# 100%|██████████| 5/5 [01:53<00:00, 22.63s/it]
# Epoch: [5/5]
# Train loss is: 0.0
# Validation loss is: 0.0
# Train accuracy is: 100.0 %
# Train accuracy for pixels is: 100.0 %
# Validation accuracy is: 100.0 %
# Validation accuracy for pixels is: 100.0 %
# /usr/local/lib/python3.6/dist-packages/torch/storage.py:34: FutureWarning: pickle support for Storage will be removed in 1.5. Use `torch.save` instead
#   warnings.warn("pickle support for Storage will be removed in 1.5. Use `torch.save` instead", FutureWarning)

# %%
compare_plots(load_results(path, 'FullyCon__predictions_T2'), n=5) # 5 correct predictions

# %% [markdown]
# ## LSTM

# %%
# Training with attention
LSTM_result_T2, LSTM_predictions_T2, LSTM_wrong_pred_T2 = evaluate_metrics(TaskSolver(), 
                                                                            data, 
                                                                            LSTM, CrossEntropyLoss, 
                                                                            attention = 'yes',
                                                                            n_epoch=5, device=device,
                                                                            lr = 0.1, verbose=True)

save_results(path, [LSTM_result_T2, LSTM_predictions_T2, LSTM_wrong_pred_T2], 
             ['LSTM_result_T2', 'LSTM_predictions_T2', 'LSTM_wrong_pred_T2'])


plot_metrics(load_results(path, 'LSTM_result_T2'))

output.eval_js('new Audio("https://upload.wikimedia.org/wikipedia/commons/0/05/Beep-09.ogg").play()')
# Out:
#  20%|████████████████▊                                                                   | 1/5 [00:55<03:42, 55.71s/it]
# Epoch: [1/5]
# Train loss is: 1.254529588842392
# Validation loss is: 1.2542351961135865
# Train accuracy is: 54.45 %
# Train accuracy for pixels is: 98.73472222222222 %
# Validation accuracy is: 52.0 %
# Validation accuracy for pixels is: 98.66666666666667 %
#  40%|█████████████████████████████████▌                                                  | 2/5 [01:55<02:50, 56.83s/it]
# Epoch: [2/5]
# Train loss is: 1.2545520948529243
# Validation loss is: 1.2543704617023468
# Train accuracy is: 68.23 %
# Train accuracy for pixels is: 99.1175 %
# Validation accuracy is: 65.0 %
# Validation accuracy for pixels is: 99.02777777777777 %
#  60%|██████████████████████████████████████████████████▍                                 | 3/5 [02:56<01:56, 58.25s/it]
# Epoch: [3/5]
# Train loss is: 1.253657597219944
# Validation loss is: 1.2535412049293517
# Train accuracy is: 35.88 %
# Train accuracy for pixels is: 98.21888888888888 %
# Validation accuracy is: 41.0 %
# Validation accuracy for pixels is: 98.36111111111111 %
#  80%|███████████████████████████████████████████████████████████████████▏                | 4/5 [03:56<00:58, 58.69s/it]
# Epoch: [4/5]
# Train loss is: 1.2346240566849709
# Validation loss is: 1.235238938331604
# Train accuracy is: 90.63 %
# Train accuracy for pixels is: 99.73972222222223 %
# Validation accuracy is: 87.0 %
# Validation accuracy for pixels is: 99.63888888888889 %
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [04:57<00:00, 59.55s/it]
# Epoch: [5/5]
# Train loss is: 1.2582936151504516
# Validation loss is: 1.2582791531085968
# Train accuracy is: 37.39 %
# Train accuracy for pixels is: 98.11722222222222 %
# Validation accuracy is: 37.0 %
# Validation accuracy for pixels is: 98.02777777777777 %
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-67-94f303e91c46> in <module>
#      13 plot_metrics(load_results(path, 'LSTM_result_T2'))
#      14
# ---> 15 output.eval_js('new Audio("https://upload.wikimedia.org/wikipedia/commons/0/05/Beep-09.ogg").play()')
#
# NameError: name 'output' is not defined

# %%
compare_plots(load_results(path, 'LSTM_wrong_pred_T2'), n=5) # 5 wrong predictions

# %%
# Training without attention
LSTM_no_result_T2, LSTM_no_predictions_T2, LSTM_no_wrong_pred_T2 = evaluate_metrics(TaskSolver(), 
                                                                            data, 
                                                                            LSTM, CrossEntropyLoss, 
                                                                            attention = None,
                                                                            n_epoch=5, device=device,
                                                                            lr = 0.1, verbose=True)

save_results(path, [LSTM_no_result_T2, LSTM_no_predictions_T2, LSTM_no_wrong_pred_T2], 
             ['LSTM_no_result_T2', 'LSTM_no_predictions_T2', 'LSTM_no_wrong_pred_T2'])


plot_metrics(load_results(path, 'LSTM_no_result_T2'))

output.eval_js('new Audio("https://upload.wikimedia.org/wikipedia/commons/0/05/Beep-09.ogg").play()')
# Out:
#  20%|████████████████▊                                                                   | 1/5 [00:50<03:22, 50.69s/it]
# Epoch: [1/5]
# Train loss is: 1.3132646842002869
# Validation loss is: 1.313022668361664
# Train accuracy is: 0.0 %
# Train accuracy for pixels is: 92.31138888888889 %
# Validation accuracy is: 0.0 %
# Validation accuracy for pixels is: 92.16666666666667 %
#  40%|█████████████████████████████████▌                                                  | 2/5 [01:40<02:31, 50.49s/it]
# Epoch: [2/5]
# Train loss is: 1.312529407441616
# Validation loss is: 1.3123013615608214
# Train accuracy is: 0.0 %
# Train accuracy for pixels is: 92.33 %
# Validation accuracy is: 0.0 %
# Validation accuracy for pixels is: 92.19444444444444 %
#  60%|██████████████████████████████████████████████████▍                                 | 3/5 [02:30<01:40, 50.32s/it]
# Epoch: [3/5]
# Train loss is: 1.3101661100625992
# Validation loss is: 1.309530303478241
# Train accuracy is: 0.0 %
# Train accuracy for pixels is: 93.56583333333333 %
# Validation accuracy is: 0.0 %
# Validation accuracy for pixels is: 93.69444444444444 %
#  80%|███████████████████████████████████████████████████████████████████▏                | 4/5 [03:19<00:49, 49.74s/it]
# Epoch: [4/5]
# Train loss is: 1.319879993712902
# Validation loss is: 1.3197619795799256
# Train accuracy is: 0.0 %
# Train accuracy for pixels is: 92.30361111111111 %
# Validation accuracy is: 0.0 %
# Validation accuracy for pixels is: 92.5 %
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [04:06<00:00, 49.34s/it]
# Epoch: [5/5]
# Train loss is: 1.3169225753068925
# Validation loss is: 1.3166554546356202
# Train accuracy is: 0.0 %
# Train accuracy for pixels is: 92.26444444444445 %
# Validation accuracy is: 0.0 %
# Validation accuracy for pixels is: 92.47222222222223 %
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-69-e2af6b21fd5c> in <module>
#      13 plot_metrics(load_results(path, 'LSTM_no_result_T2'))
#      14
# ---> 15 output.eval_js('new Audio("https://upload.wikimedia.org/wikipedia/commons/0/05/Beep-09.ogg").play()')
#
# NameError: name 'output' is not defined

# %%
compare_plots(load_results(path, 'LSTM_no_wrong_pred_T2'), n=5) # 5 wrong predictions

# %% [markdown]
# ## CNN

# %%
# Training
CNN_result_T2, CNN_predictions_T2, CNN_wrong_pred_T2 = evaluate_metrics(TaskSolver(), 
                                                                            data, 
                                                                            CNN, CrossEntropyLoss, 
                                                                            attention = 'yes',
                                                                            n_epoch=5, device=device,
                                                                            lr = 0.1, verbose=True)

save_results(path, [CNN_result_T2, CNN_predictions_T2, CNN_wrong_pred_T2], 
             ['CNN_result_T2', 'CNN_predictions_T2', 'CNN_wrong_pred_T2'])


plot_metrics(load_results(path, 'CNN_result_T2'))

output.eval_js('new Audio("https://upload.wikimedia.org/wikipedia/commons/0/05/Beep-09.ogg").play()')
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
#  20%|██        | 1/5 [00:37<02:30, 37.68s/it]
# Epoch: [1/5]
# Train loss is: 0.29487039031758905
# Validation loss is: 0.2889828985929489
# Train accuracy is: 0.2 %
# Train accuracy for pixels is: 90.16472222222222 %
# Validation accuracy is: 1.0 %
# Validation accuracy for pixels is: 90.19444444444444 %
#  40%|████      | 2/5 [01:15<01:52, 37.59s/it]
# Epoch: [2/5]
# Train loss is: 0.2948686616718769
# Validation loss is: 0.28898106291890147
# Train accuracy is: 0.2 %
# Train accuracy for pixels is: 90.16472222222222 %
# Validation accuracy is: 1.0 %
# Validation accuracy for pixels is: 90.19444444444444 %
#  60%|██████    | 3/5 [01:53<01:15, 37.77s/it]
# Epoch: [3/5]
# Train loss is: 0.29486867435052994
# Validation loss is: 0.28898106709122656
# Train accuracy is: 0.2 %
# Train accuracy for pixels is: 90.16472222222222 %
# Validation accuracy is: 1.0 %
# Validation accuracy for pixels is: 90.19444444444444 %
#  80%|████████  | 4/5 [02:30<00:37, 37.76s/it]
# Epoch: [4/5]
# Train loss is: 0.29486868816614153
# Validation loss is: 0.28898107722401617
# Train accuracy is: 0.2 %
# Train accuracy for pixels is: 90.16472222222222 %
# Validation accuracy is: 1.0 %
# Validation accuracy for pixels is: 90.19444444444444 %
# 100%|██████████| 5/5 [03:08<00:00, 37.71s/it]
# Epoch: [5/5]
# Train loss is: 0.29486867403015493
# Validation loss is: 0.28898106470704077
# Train accuracy is: 0.2 %
# Train accuracy for pixels is: 90.16472222222222 %
# Validation accuracy is: 1.0 %
# Validation accuracy for pixels is: 90.19444444444444 %
# /usr/local/lib/python3.6/dist-packages/torch/storage.py:34: FutureWarning: pickle support for Storage will be removed in 1.5. Use `torch.save` instead
#   warnings.warn("pickle support for Storage will be removed in 1.5. Use `torch.save` instead", FutureWarning)

# %%
compare_plots(load_results(path, 'CNN_wrong_pred_T2'), n=5) # 5 wrong predictions

# %%
# Training wihtout attention
CNN_no_result_T2, CNN_no_predictions_T2, CNN_no_wrong_pred_T2 = evaluate_metrics(TaskSolver(), 
                                                                            data, 
                                                                            CNN, CrossEntropyLoss, 
                                                                            attention = None,
                                                                            n_epoch=5, device=device,
                                                                            lr = 0.1, verbose=True)

save_results(path, [CNN_no_result_T2, CNN_no_predictions_T2, CNN_no_wrong_pred_T2], 
             ['CNN_no_result_T2', 'CNN_no_predictions_T2', 'CNN_no_wrong_pred_T2'])


plot_metrics(load_results(path, 'CNN_no_result_T2'))

output.eval_js('new Audio("https://upload.wikimedia.org/wikipedia/commons/0/05/Beep-09.ogg").play()')
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
#  20%|██        | 1/5 [00:27<01:48, 27.23s/it]
# Epoch: [1/5]
# Train loss is: 0.2940655127495527
# Validation loss is: 0.29942549362778664
# Train accuracy is: 0.29 %
# Train accuracy for pixels is: 90.15722222222222 %
# Validation accuracy is: 0.0 %
# Validation accuracy for pixels is: 90.16666666666667 %
#  40%|████      | 2/5 [00:54<01:21, 27.21s/it]
# Epoch: [2/5]
# Train loss is: 0.29406403870135545
# Validation loss is: 0.29942416831851004
# Train accuracy is: 0.29 %
# Train accuracy for pixels is: 90.15722222222222 %
# Validation accuracy is: 0.0 %
# Validation accuracy for pixels is: 90.16666666666667 %
#  60%|██████    | 3/5 [01:21<00:54, 27.27s/it]
# Epoch: [3/5]
# Train loss is: 0.2940640544913709
# Validation loss is: 0.29942418724298475
# Train accuracy is: 0.29 %
# Train accuracy for pixels is: 90.15722222222222 %
# Validation accuracy is: 0.0 %
# Validation accuracy for pixels is: 90.16666666666667 %
#  80%|████████  | 4/5 [01:49<00:27, 27.32s/it]
# Epoch: [4/5]
# Train loss is: 0.29406405896246435
# Validation loss is: 0.2994241954386234
# Train accuracy is: 0.29 %
# Train accuracy for pixels is: 90.15722222222222 %
# Validation accuracy is: 0.0 %
# Validation accuracy for pixels is: 90.16666666666667 %
# 100%|██████████| 5/5 [02:16<00:00, 27.30s/it]
# Epoch: [5/5]
# Train loss is: 0.29406405402868985
# Validation loss is: 0.2994241860508919
# Train accuracy is: 0.29 %
# Train accuracy for pixels is: 90.15722222222222 %
# Validation accuracy is: 0.0 %
# Validation accuracy for pixels is: 90.16666666666667 %
# /usr/local/lib/python3.6/dist-packages/torch/storage.py:34: FutureWarning: pickle support for Storage will be removed in 1.5. Use `torch.save` instead
#   warnings.warn("pickle support for Storage will be removed in 1.5. Use `torch.save` instead", FutureWarning)

# %%
compare_plots(load_results(path, 'CNN_no_wrong_pred_T2'), n=5) # 5 wrong predictions

# %%
CNNB_result_T2, CNNB_predictions_T2, CNNB_wrong_pred_T2 = evaluate_metrics(TaskSolver(), 
                                                                            data, 
                                                                            CNN_big, CrossEntropyLoss, 
                                                                            attention = 'yes',
                                                                            n_epoch=5, device=device,
                                                                            lr = 0.1, verbose=True)

save_results(path, [CNN_result_T2, CNN_predictions_T2, CNN_wrong_pred_T2], 
             ['CNN_result_T2', 'CNN_predictions_T2', 'CNN_wrong_pred_T2'])


plot_metrics(load_results(path,'CNN_result_T1'))
# Out:
#  20%|████████████████▊                                                                   | 1/5 [00:57<03:51, 57.78s/it]
# Epoch: [1/5]
# Train loss is: 11.149777895331383
# Validation loss is: 9.289144515991211
# Train accuracy is: 94.98 %
# Train accuracy for pixels is: 99.84944444444444 %
# Validation accuracy is: 95.0 %
# Validation accuracy for pixels is: 99.83333333333333 %
#  40%|█████████████████████████████████▌                                                  | 2/5 [01:55<02:53, 57.84s/it]
# Epoch: [2/5]
# Train loss is: 0.603770517873764
# Validation loss is: 0.0
# Train accuracy is: 99.52 %
# Train accuracy for pixels is: 99.98666666666666 %
# Validation accuracy is: 100.0 %
# Validation accuracy for pixels is: 100.0 %
#  60%|██████████████████████████████████████████████████▍                                 | 3/5 [02:54<01:56, 58.05s/it]
# Epoch: [3/5]
# Train loss is: 0.020543109893798827
# Validation loss is: 0.0
# Train accuracy is: 99.98 %
# Train accuracy for pixels is: 99.99944444444445 %
# Validation accuracy is: 100.0 %
# Validation accuracy for pixels is: 100.0 %
#  80%|███████████████████████████████████████████████████████████████████▏                | 4/5 [03:56<00:59, 59.26s/it]
# Epoch: [4/5]
# Train loss is: 0.0
# Validation loss is: 0.0
# Train accuracy is: 100.0 %
# Train accuracy for pixels is: 100.0 %
# Validation accuracy is: 100.0 %
# Validation accuracy for pixels is: 100.0 %
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [04:54<00:00, 58.95s/it]
# Epoch: [5/5]
# Train loss is: 0.0
# Validation loss is: 0.0
# Train accuracy is: 100.0 %
# Train accuracy for pixels is: 100.0 %
# Validation accuracy is: 100.0 %
# Validation accuracy for pixels is: 100.0 %

# %% [markdown]
# # Task 3

# %%
task=task_builder(gener_three, 5, 2)
plot_task(task)
# input.shape == output.shape and inputs have same shape between each others

# %% [markdown]
# ## FCN

# %%
# Training
FullyCon_result_T3, FullyCon_predictions_T3, FullyCon_wrong_pred_T3 = evaluate_metrics(TaskSolver(), 
                                                                                        [task_builder(gener_three, 10000, 100)], 
                                                                                        FullyCon, CrossEntropyLoss, 
                                                                                        n_epoch=5, device=device,
                                                                                        lr = 0.1, verbose=True, attention = False)

save_results(path, [FullyCon_result_T3, FullyCon_predictions_T3, FullyCon_wrong_pred_T3], 
             ['FullyCon_result_T3', 'FullyCon_predictions_T3', 'FullyCon_wrong_pred_T3'])


plot_metrics(load_results(path, 'FullyCon_result_T3'))

output.eval_js('new Audio("https://upload.wikimedia.org/wikipedia/commons/0/05/Beep-09.ogg").play()')
# Out:
#  20%|██        | 1/5 [00:57<03:51, 57.81s/it]
# Epoch: [1/5]
# Train loss is: 1.0939277419900522
# Validation loss is: 1.3991408635675908
# Train accuracy is: 4.08 %
# Train accuracy for pixels is: 98.4837109375 %
# Validation accuracy is: 3.0 %
# Validation accuracy for pixels is: 98.05078125 %
#  40%|████      | 2/5 [01:55<02:53, 57.86s/it]
# Epoch: [2/5]
# Train loss is: 0.4442614922344219
# Validation loss is: 0.5367562298476696
# Train accuracy is: 35.14 %
# Train accuracy for pixels is: 99.4937109375 %
# Validation accuracy is: 29.0 %
# Validation accuracy for pixels is: 99.30859375 %
#  60%|██████    | 3/5 [02:53<01:55, 57.93s/it]
# Epoch: [3/5]
# Train loss is: 0.2626632583448663
# Validation loss is: 0.4917033168300986
# Train accuracy is: 58.98 %
# Train accuracy for pixels is: 99.7319921875 %
# Validation accuracy is: 43.0 %
# Validation accuracy for pixels is: 99.5078125 %
#  80%|████████  | 4/5 [03:51<00:57, 57.92s/it]
# Epoch: [4/5]
# Train loss is: 0.1789536977492273
# Validation loss is: 0.33939051628112793
# Train accuracy is: 72.35 %
# Train accuracy for pixels is: 99.83234375 %
# Validation accuracy is: 46.0 %
# Validation accuracy for pixels is: 99.63671875 %
# 100%|██████████| 5/5 [04:49<00:00, 57.87s/it]
# Epoch: [5/5]
# Train loss is: 0.12451683158092201
# Validation loss is: 0.31724295556545257
# Train accuracy is: 80.77 %
# Train accuracy for pixels is: 99.8884375 %
# Validation accuracy is: 55.0 %
# Validation accuracy for pixels is: 99.7265625 %
# /usr/local/lib/python3.6/dist-packages/torch/storage.py:34: FutureWarning: pickle support for Storage will be removed in 1.5. Use `torch.save` instead
#   warnings.warn("pickle support for Storage will be removed in 1.5. Use `torch.save` instead", FutureWarning)

# %%
compare_plots(load_results(path, 'FullyCon_wrong_pred_T3'), n=5) # 5 wrong predictions

# %% [markdown]
# ## LSTM

# %%
# Training with attention
LSTM_result_T3, LSTM_predictions_T3, LSTM_wrong_pred_T3 = evaluate_metrics(TaskSolver(), 
                                                                            [task_builder(gener_three, 10000, 100)], 
                                                                            LSTM, CrossEntropyLoss, 
                                                                            attention = 'yes',
                                                                            n_epoch=5, device=device,
                                                                            lr = 0.1, verbose=True)

save_results(path, [LSTM_result_T3, LSTM_predictions_T3, LSTM_wrong_pred_T3], 
             ['LSTM_result_T3', 'LSTM_predictions_T3', 'LSTM_wrong_pred_T3'])


plot_metrics(load_results(path, 'LSTM_result_T3'))

output.eval_js('new Audio("https://upload.wikimedia.org/wikipedia/commons/0/05/Beep-09.ogg").play()')
# Out:
#  20%|██        | 1/5 [00:51<03:26, 51.54s/it]
# Epoch: [1/5]
# Train loss is: 2.2268527382850647
# Validation loss is: 2.2265233397483826
# Train accuracy is: 0.0 %
# Train accuracy for pixels is: 13.689453125 %
# Validation accuracy is: 0.0 %
# Validation accuracy for pixels is: 13.9765625 %
#  40%|████      | 2/5 [01:43<02:35, 51.73s/it]
# Epoch: [2/5]
# Train loss is: 2.2242849789381025
# Validation loss is: 2.224114513397217
# Train accuracy is: 0.0 %
# Train accuracy for pixels is: 13.9311328125 %
# Validation accuracy is: 0.0 %
# Validation accuracy for pixels is: 14.265625 %
#  60%|██████    | 3/5 [02:35<01:43, 51.66s/it]
# Epoch: [3/5]
# Train loss is: 2.223333328771591
# Validation loss is: 2.2232776832580567
# Train accuracy is: 0.0 %
# Train accuracy for pixels is: 13.737265625 %
# Validation accuracy is: 0.0 %
# Validation accuracy for pixels is: 14.07421875 %
#  80%|████████  | 4/5 [03:26<00:51, 51.57s/it]
# Epoch: [4/5]
# Train loss is: 2.223169305586815
# Validation loss is: 2.22289826631546
# Train accuracy is: 0.0 %
# Train accuracy for pixels is: 13.7441796875 %
# Validation accuracy is: 0.0 %
# Validation accuracy for pixels is: 14.0625 %
# 100%|██████████| 5/5 [04:18<00:00, 51.60s/it]
# Epoch: [5/5]
# Train loss is: 2.222445882177353
# Validation loss is: 2.2222119474411013
# Train accuracy is: 0.0 %
# Train accuracy for pixels is: 13.7822265625 %
# Validation accuracy is: 0.0 %
# Validation accuracy for pixels is: 14.09765625 %
# /usr/local/lib/python3.6/dist-packages/torch/storage.py:34: FutureWarning: pickle support for Storage will be removed in 1.5. Use `torch.save` instead
#   warnings.warn("pickle support for Storage will be removed in 1.5. Use `torch.save` instead", FutureWarning)

# %%
compare_plots(load_results(path, 'LSTM_wrong_pred_T3'), n=5) # 5 wrong predictions

# %%
# Training
LSTM_no_result_T3, LSTM_no_predictions_T3, LSTM_no_wrong_pred_T3 = evaluate_metrics(TaskSolver(), 
                                                                            [task_builder(gener_three, 10000, 100)], 
                                                                            LSTM, CrossEntropyLoss, 
                                                                            attention = None,
                                                                            n_epoch=5, device=device,
                                                                            lr = 0.1, verbose=True)

save_results(path, [LSTM_no_result_T3, LSTM_no_predictions_T3, LSTM_no_wrong_pred_T3], 
             ['LSTM_no_result_T3', 'LSTM_no_predictions_T3', 'LSTM_no_wrong_pred_T3'])


plot_metrics(load_results(path, 'LSTM_no_result_T3'))

output.eval_js('new Audio("https://upload.wikimedia.org/wikipedia/commons/0/05/Beep-09.ogg").play()')
# Out:
#  20%|██        | 1/5 [00:42<02:50, 42.71s/it]
# Epoch: [1/5]
# Train loss is: 2.206128603410721
# Validation loss is: 2.2059253430366517
# Train accuracy is: 0.0 %
# Train accuracy for pixels is: 13.791640625 %
# Validation accuracy is: 0.0 %
# Validation accuracy for pixels is: 13.78125 %
#  40%|████      | 2/5 [01:25<02:08, 42.67s/it]
# Epoch: [2/5]
# Train loss is: 2.2012790598630905
# Validation loss is: 2.2010120844841
# Train accuracy is: 0.0 %
# Train accuracy for pixels is: 14.8848828125 %
# Validation accuracy is: 0.0 %
# Validation accuracy for pixels is: 14.96484375 %
#  60%|██████    | 3/5 [02:08<01:25, 42.81s/it]
# Epoch: [3/5]
# Train loss is: 2.1950429092884063
# Validation loss is: 2.1946384072303773
# Train accuracy is: 0.0 %
# Train accuracy for pixels is: 15.32703125 %
# Validation accuracy is: 0.0 %
# Validation accuracy for pixels is: 15.359375 %
#  80%|████████  | 4/5 [02:51<00:42, 42.76s/it]
# Epoch: [4/5]
# Train loss is: 2.191105445098877
# Validation loss is: 2.1907459783554075
# Train accuracy is: 0.0 %
# Train accuracy for pixels is: 15.691640625 %
# Validation accuracy is: 0.0 %
# Validation accuracy for pixels is: 15.671875 %
# 100%|██████████| 5/5 [03:33<00:00, 42.72s/it]
# Epoch: [5/5]
# Train loss is: 2.185123551487923
# Validation loss is: 2.184621150493622
# Train accuracy is: 0.0 %
# Train accuracy for pixels is: 16.44609375 %
# Validation accuracy is: 0.0 %
# Validation accuracy for pixels is: 16.39453125 %
# /usr/local/lib/python3.6/dist-packages/torch/storage.py:34: FutureWarning: pickle support for Storage will be removed in 1.5. Use `torch.save` instead
#   warnings.warn("pickle support for Storage will be removed in 1.5. Use `torch.save` instead", FutureWarning)

# %%
compare_plots(load_results(path, 'LSTM_no_wrong_pred_T3'), n=5) # 5 wrong predictions

# %% [markdown]
# ## CNN

# %%
# Training
CNN_result_T3, CNN_predictions_T3, CNN_wrong_pred_T3 = evaluate_metrics(TaskSolver(), 
                                                                            [task_builder(gener_three, 10000, 100)], 
                                                                            CNN, CrossEntropyLoss, 
                                                                            attention = 'yes',
                                                                            n_epoch=5, device=device,
                                                                            lr = 0.1, verbose=True)

save_results(path, [CNN_result_T3, CNN_predictions_T3, CNN_wrong_pred_T3], 
             ['CNN_result_T3', 'CNN_predictions_T3', 'CNN_wrong_pred_T3'])


plot_metrics(load_results(path, 'CNN_result_T3'))

output.eval_js('new Audio("https://upload.wikimedia.org/wikipedia/commons/0/05/Beep-09.ogg").play()')
# Out:
#  20%|██        | 1/5 [00:37<02:28, 37.17s/it]
# Epoch: [1/5]
# Train loss is: 0.27037801820114254
# Validation loss is: 0.26525907546281813
# Train accuracy is: 0.0 %
# Train accuracy for pixels is: 94.2046875 %
# Validation accuracy is: 0.0 %
# Validation accuracy for pixels is: 94.18359375 %
#  40%|████      | 2/5 [01:14<01:51, 37.24s/it]
# Epoch: [2/5]
# Train loss is: 0.27038752113841474
# Validation loss is: 0.2652854371070862
# Train accuracy is: 0.0 %
# Train accuracy for pixels is: 94.2046875 %
# Validation accuracy is: 0.0 %
# Validation accuracy for pixels is: 94.18359375 %
#  60%|██████    | 3/5 [01:51<01:14, 37.26s/it]
# Epoch: [3/5]
# Train loss is: 0.27038318149000407
# Validation loss is: 0.2652930587530136
# Train accuracy is: 0.0 %
# Train accuracy for pixels is: 94.204453125 %
# Validation accuracy is: 0.0 %
# Validation accuracy for pixels is: 94.18359375 %
#  80%|████████  | 4/5 [02:30<00:37, 37.70s/it]
# Epoch: [4/5]
# Train loss is: 0.270381628356874
# Validation loss is: 0.2653016682714224
# Train accuracy is: 0.0 %
# Train accuracy for pixels is: 94.204453125 %
# Validation accuracy is: 0.0 %
# Validation accuracy for pixels is: 94.18359375 %
# 100%|██████████| 5/5 [03:09<00:00, 37.81s/it]
# Epoch: [5/5]
# Train loss is: 0.27038187516331674
# Validation loss is: 0.2653105635941029
# Train accuracy is: 0.0 %
# Train accuracy for pixels is: 94.2044921875 %
# Validation accuracy is: 0.0 %
# Validation accuracy for pixels is: 94.1796875 %
# /usr/local/lib/python3.6/dist-packages/torch/storage.py:34: FutureWarning: pickle support for Storage will be removed in 1.5. Use `torch.save` instead
#   warnings.warn("pickle support for Storage will be removed in 1.5. Use `torch.save` instead", FutureWarning)

# %%
compare_plots(load_results(path, 'CNN_wrong_pred_T3'), n=5) # 5 wrong predictions

# %%
# Training
CNN_no_result_T3, CNN_no_predictions_T3, CNN_no_wrong_pred_T3 = evaluate_metrics(TaskSolver(), 
                                                                            [task_builder(gener_three, 10000, 100)], 
                                                                            CNN, CrossEntropyLoss, 
                                                                            attention = None,
                                                                            n_epoch=5, device=device,
                                                                            lr = 0.1, verbose=True)

save_results(path, [CNN_no_result_T3, CNN_no_predictions_T3, CNN_no_wrong_pred_T3], 
             ['CNN_no_result_T3', 'CNN_no_predictions_T3', 'CNN_no_wrong_pred_T3'])


plot_metrics(load_results(path, 'CNN_no_result_T3'))

output.eval_js('new Audio("https://upload.wikimedia.org/wikipedia/commons/0/05/Beep-09.ogg").play()')
# Out:
#  20%|██        | 1/5 [00:28<01:53, 28.49s/it]
# Epoch: [1/5]
# Train loss is: 0.26333066347837447
# Validation loss is: 0.26066153712570667
# Train accuracy is: 0.0 %
# Train accuracy for pixels is: 94.2464453125 %
# Validation accuracy is: 0.0 %
# Validation accuracy for pixels is: 94.26171875 %
#  40%|████      | 2/5 [00:56<01:24, 28.21s/it]
# Epoch: [2/5]
# Train loss is: 0.26348647470623254
# Validation loss is: 0.26082715421915054
# Train accuracy is: 0.0 %
# Train accuracy for pixels is: 94.2465234375 %
# Validation accuracy is: 0.0 %
# Validation accuracy for pixels is: 94.26953125 %
#  60%|██████    | 3/5 [01:24<00:56, 28.15s/it]
# Epoch: [3/5]
# Train loss is: 0.26352471482045947
# Validation loss is: 0.26086422100663187
# Train accuracy is: 0.0 %
# Train accuracy for pixels is: 94.2465625 %
# Validation accuracy is: 0.0 %
# Validation accuracy for pixels is: 94.26953125 %
#  80%|████████  | 4/5 [01:51<00:27, 27.99s/it]
# Epoch: [4/5]
# Train loss is: 0.2635595436967909
# Validation loss is: 0.2608972804993391
# Train accuracy is: 0.0 %
# Train accuracy for pixels is: 94.246640625 %
# Validation accuracy is: 0.0 %
# Validation accuracy for pixels is: 94.26953125 %
# 100%|██████████| 5/5 [02:19<00:00, 27.83s/it]
# Epoch: [5/5]
# Train loss is: 0.26359191480949523
# Validation loss is: 0.260927609577775
# Train accuracy is: 0.0 %
# Train accuracy for pixels is: 94.2469140625 %
# Validation accuracy is: 0.0 %
# Validation accuracy for pixels is: 94.2734375 %
# /usr/local/lib/python3.6/dist-packages/torch/storage.py:34: FutureWarning: pickle support for Storage will be removed in 1.5. Use `torch.save` instead
#   warnings.warn("pickle support for Storage will be removed in 1.5. Use `torch.save` instead", FutureWarning)

# %%
compare_plots(load_results(path, 'CNN_no_wrong_pred_T3'), n=5) # 5 wrong predictions

# %% [markdown]
# # Task 4

# %%
from importlib import reload  
import models
models = reload(models)
from models import *

# %%
task=task_builder(gener_four, 5, 2)
plot_task(task)

# %%
data=[task_builder(gener_four, 10000, 100)]

# %% [markdown]
# ## FCN

# %%
# Training
FullyCon_result_T4, FullyCon_predictions_T4, FullyCon_wrong_pred_T4 = evaluate_metrics(TaskSolver(), 
                                                                                        data, 
                                                                                        FullyCon_T4, CrossEntropyLoss, 
                                                                                        n_epoch=5, device=device,
                                                                                        lr = 0.1, verbose=True)

save_results(path, [FullyCon_result_T4, FullyCon_predictions_T4, FullyCon_wrong_pred_T4 ], 
             ['FullyCon_result_T4', 'FullyCon_predictions_T4', 'FullyCon_wrong_pred_T4' ])


plot_metrics(load_results(path, 'FullyCon_result_T4'))

output.eval_js('new Audio("https://upload.wikimedia.org/wikipedia/commons/0/05/Beep-09.ogg").play()')
# Out:
#  20%|████████████████▌                                                                  | 1/5 [02:57<11:48, 177.10s/it]
# Epoch: [1/5]
# Train loss is: 1.0713827600655554
# Validation loss is: 1.4942137186961009
# Train accuracy is: 5.79 %
# Train accuracy for pixels is: 98.22893790842394 %
# Validation accuracy is: 9.0 %
# Validation accuracy for pixels is: 97.80436868544336 %
#  40%|█████████████████████████████████▏                                                 | 2/5 [05:54<08:51, 177.07s/it]
# Epoch: [2/5]
# Train loss is: 0.7591552795332516
# Validation loss is: 1.2884169209162797
# Train accuracy is: 18.24 %
# Train accuracy for pixels is: 98.96243056514516 %
# Validation accuracy is: 11.0 %
# Validation accuracy for pixels is: 98.47603996161878 %
#  60%|█████████████████████████████████████████████████▊                                 | 3/5 [08:52<05:54, 177.37s/it]
# Epoch: [3/5]
# Train loss is: 0.4250996367336922
# Validation loss is: 1.1327499854521192
# Train accuracy is: 36.22 %
# Train accuracy for pixels is: 99.40164639116935 %
# Validation accuracy is: 16.0 %
# Validation accuracy for pixels is: 98.77518767285657 %
#  80%|██████████████████████████████████████████████████████████████████▍                | 4/5 [11:49<02:57, 177.41s/it]
# Epoch: [4/5]
# Train loss is: 0.3055871018350423
# Validation loss is: 0.954004236807426
# Train accuracy is: 49.0 %
# Train accuracy for pixels is: 99.58678744359462 %
# Validation accuracy is: 17.0 %
# Validation accuracy for pixels is: 99.01789241970988 %
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [14:46<00:00, 177.29s/it]
# Epoch: [5/5]
# Train loss is: 0.23435705177227706
# Validation loss is: 0.9269609882649092
# Train accuracy is: 57.75 %
# Train accuracy for pixels is: 99.68645736354686 %
# Validation accuracy is: 19.0 %
# Validation accuracy for pixels is: 99.10820116272507 %
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-73-9e82e0768738> in <module>
#      12 plot_metrics(load_results(path, 'FullyCon_result_T4'))
#      13
# ---> 14 output.eval_js('new Audio("https://upload.wikimedia.org/wikipedia/commons/0/05/Beep-09.ogg").play()')
#
# NameError: name 'output' is not defined

# %%
compare_plots(load_results(path, 'FullyCon_wrong_pred_T4'), n=5) # 5 wrong predictions

# %% [markdown]
# ## LSTM

# %%
# Training with attention
LSTM_result_T4, LSTM_predictions_T4, LSTM_wrong_pred_T4 = evaluate_metrics(TaskSolver(), 
                                                                            [task_builder(gener_four, 10000, 100)], 
                                                                            LSTM_T4, CrossEntropyLoss, 
                                                                            attention = 'yes',
                                                                            n_epoch=5, device=device,
                                                                            lr = 0.1, verbose=True)

save_results(path, [LSTM_result_T4, LSTM_predictions_T4, LSTM_wrong_pred_T4], 
             ['LSTM_result_T4', 'LSTM_predictions_T4', 'LSTM_wrong_pred_T4'])


plot_metrics(load_results(path, 'LSTM_result_T4'))

output.eval_js('new Audio("https://upload.wikimedia.org/wikipedia/commons/0/05/Beep-09.ogg").play()')
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
#  20%|██        | 1/5 [00:59<03:57, 59.36s/it]
# Epoch: [1/5]
# Train loss is: 1.8016780987739562
# Validation loss is: 1.798537734746933
# Train accuracy is: 0.0 %
# Train accuracy for pixels is: 63.22920348670477 %
# Validation accuracy is: 0.0 %
# Validation accuracy for pixels is: 63.594444132036216 %
#  40%|████      | 2/5 [01:59<02:58, 59.46s/it]
# Epoch: [2/5]
# Train loss is: 1.7563558579087257
# Validation loss is: 1.7517549216747283
# Train accuracy is: 0.0 %
# Train accuracy for pixels is: 68.4441991627818 %
# Validation accuracy is: 0.0 %
# Validation accuracy for pixels is: 68.45301692627791 %
#  60%|██████    | 3/5 [02:59<01:59, 59.66s/it]
# Epoch: [3/5]
# Train loss is: 1.7443140179038048
# Validation loss is: 1.7416774678230285
# Train accuracy is: 0.0 %
# Train accuracy for pixels is: 69.747267258455 %
# Validation accuracy is: 0.0 %
# Validation accuracy for pixels is: 69.90384074678063 %
#  80%|████████  | 4/5 [03:59<00:59, 59.71s/it]
# Epoch: [4/5]
# Train loss is: 1.7358912340641022
# Validation loss is: 1.7345479154586791
# Train accuracy is: 0.0 %
# Train accuracy for pixels is: 71.07729040089102 %
# Validation accuracy is: 0.0 %
# Validation accuracy for pixels is: 71.14660068604847 %
# 100%|██████████| 5/5 [04:58<00:00, 59.75s/it]
# Epoch: [5/5]
# Train loss is: 1.6962810232281684
# Validation loss is: 1.6918834328651429
# Train accuracy is: 0.0 %
# Train accuracy for pixels is: 73.4432765776761 %
# Validation accuracy is: 0.0 %
# Validation accuracy for pixels is: 73.851431142102 %
# /usr/local/lib/python3.6/dist-packages/torch/storage.py:34: FutureWarning: pickle support for Storage will be removed in 1.5. Use `torch.save` instead
#   warnings.warn("pickle support for Storage will be removed in 1.5. Use `torch.save` instead", FutureWarning)

# %%
compare_plots(load_results(path, 'LSTM_wrong_pred_T4'), n=5) # 5 wrong predictions

# %%
# Training without attention
LSTM_no_result_T4, LSTM_no_predictions_T4, LSTM_no_wrong_pred_T4 = evaluate_metrics(TaskSolver(), 
                                                                            [task_builder(gener_four, 10000, 100)], 
                                                                            LSTM_T4, CrossEntropyLoss, 
                                                                            attention = None,
                                                                            n_epoch=5, device=device,
                                                                            lr = 0.1, verbose=True)

save_results(path, [LSTM_no_result_T4, LSTM_no_predictions_T4, LSTM_no_wrong_pred_T4], 
             ['LSTM_no_result_T4', 'LSTM_no_predictions_T4', 'LSTM_no_wrong_pred_T4'])


plot_metrics(load_results(path, 'LSTM_no_result_T4'))

output.eval_js('new Audio("https://upload.wikimedia.org/wikipedia/commons/0/05/Beep-09.ogg").play()')
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
#  20%|██        | 1/5 [00:50<03:20, 50.06s/it]
# Epoch: [1/5]
# Train loss is: 1.9449689069628715
# Validation loss is: 1.954413046836853
# Train accuracy is: 0.0 %
# Train accuracy for pixels is: 59.61844967404997 %
# Validation accuracy is: 0.0 %
# Validation accuracy for pixels is: 58.411633109619686 %
#  40%|████      | 2/5 [01:39<02:30, 50.01s/it]
# Epoch: [2/5]
# Train loss is: 1.9477541654467583
# Validation loss is: 1.9554027819633484
# Train accuracy is: 0.0 %
# Train accuracy for pixels is: 59.4490425322191 %
# Validation accuracy is: 0.0 %
# Validation accuracy for pixels is: 58.42841163310962 %
#  60%|██████    | 3/5 [02:29<01:39, 49.96s/it]
# Epoch: [3/5]
# Train loss is: 1.9445129672646522
# Validation loss is: 1.950956038236618
# Train accuracy is: 0.0 %
# Train accuracy for pixels is: 59.75271680717101 %
# Validation accuracy is: 0.0 %
# Validation accuracy for pixels is: 58.624161073825505 %
#  80%|████████  | 4/5 [03:20<00:50, 50.08s/it]
# Epoch: [4/5]
# Train loss is: 1.9424270353198052
# Validation loss is: 1.9492572402954103
# Train accuracy is: 0.0 %
# Train accuracy for pixels is: 59.789694565940145 %
# Validation accuracy is: 0.0 %
# Validation accuracy for pixels is: 58.84228187919463 %
# 100%|██████████| 5/5 [04:09<00:00, 50.00s/it]
# Epoch: [5/5]
# Train loss is: 1.929217993760109
# Validation loss is: 1.9365575814247131
# Train accuracy is: 0.0 %
# Train accuracy for pixels is: 61.021321242051734 %
# Validation accuracy is: 0.0 %
# Validation accuracy for pixels is: 59.93288590604027 %
# /usr/local/lib/python3.6/dist-packages/torch/storage.py:34: FutureWarning: pickle support for Storage will be removed in 1.5. Use `torch.save` instead
#   warnings.warn("pickle support for Storage will be removed in 1.5. Use `torch.save` instead", FutureWarning)

# %%
compare_plots(load_results(path, 'LSTM_no_wrong_pred_T4'), n=5) # 5 wrong predictions

# %% [markdown]
# ## CNN

# %%
# Training with attention
CNN_result_T4, CNN_predictions_T4, CNN_wrong_pred_T4 = evaluate_metrics(TaskSolver(), 
                                                                        [task_builder(gener_four, 10000, 100)], 
                                                                        CNN_T4, CrossEntropyLoss, 
                                                                        attention = 'yes',
                                                                        n_epoch=5, device=device,
                                                                        lr = 0.1, verbose=True)

save_results(path, [CNN_result_T4, CNN_predictions_T4, CNN_wrong_pred_T4], 
             ['CNN_result_T4', 'CNN_predictions_T4', 'CNN_wrong_pred_T4'])


plot_metrics(load_results(path, 'CNN_result_T4'))

output.eval_js('new Audio("https://upload.wikimedia.org/wikipedia/commons/0/05/Beep-09.ogg").play()')
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
#  20%|██        | 1/5 [00:42<02:51, 42.82s/it]
# Epoch: [1/5]
# Train loss is: 0.017312323719638742
# Validation loss is: 0.02987745145841316
# Train accuracy is: 74.51 %
# Train accuracy for pixels is: 99.82292521547153 %
# Validation accuracy is: 64.0 %
# Validation accuracy for pixels is: 99.73731276548178 %
#  40%|████      | 2/5 [01:25<02:08, 42.82s/it]
# Epoch: [2/5]
# Train loss is: 0.01928834794519689
# Validation loss is: 0.034919695561516084
# Train accuracy is: 75.89 %
# Train accuracy for pixels is: 99.8347524118041 %
# Validation accuracy is: 67.0 %
# Validation accuracy for pixels is: 99.76525821596245 %
#  60%|██████    | 3/5 [02:08<01:25, 42.80s/it]
# Epoch: [3/5]
# Train loss is: 0.020993787546495696
# Validation loss is: 0.03637325859696138
# Train accuracy is: 75.4 %
# Train accuracy for pixels is: 99.83125422697334 %
# Validation accuracy is: 64.0 %
# Validation accuracy for pixels is: 99.74290185557791 %
#  80%|████████  | 4/5 [02:51<00:42, 42.81s/it]
# Epoch: [4/5]
# Train loss is: 0.021303254647738818
# Validation loss is: 0.03940336141688539
# Train accuracy is: 75.39 %
# Train accuracy for pixels is: 99.8304768525665 %
# Validation accuracy is: 64.0 %
# Validation accuracy for pixels is: 99.74849094567405 %
# 100%|██████████| 5/5 [03:34<00:00, 42.86s/it]
# Epoch: [5/5]
# Train loss is: 0.020568291145560632
# Validation loss is: 0.03262090884513476
# Train accuracy is: 74.94 %
# Train accuracy for pixels is: 99.82931079095624 %
# Validation accuracy is: 65.0 %
# Validation accuracy for pixels is: 99.75408003577017 %
# /usr/local/lib/python3.6/dist-packages/torch/storage.py:34: FutureWarning: pickle support for Storage will be removed in 1.5. Use `torch.save` instead
#   warnings.warn("pickle support for Storage will be removed in 1.5. Use `torch.save` instead", FutureWarning)

# %%
compare_plots(load_results(path, 'CNN_wrong_pred_T4'), n=5) # 5 wrong predictions

# %%
# Training
CNN_no_result_T4, CNN_no_predictions_T4, CNN_no_wrong_pred_T4 = evaluate_metrics(TaskSolver(), 
                                                                            [task_builder(gener_four, 10000, 100)], 
                                                                            CNN_T4, CrossEntropyLoss, 
                                                                            attention = None,
                                                                            n_epoch=5, device=device,
                                                                            lr = 0.1, verbose=True)

save_results(path, [CNN_no_result_T4, CNN_no_predictions_T4, CNN_no_wrong_pred_T4], 
             ['CNN_no_result_T4', 'CNN_no_predictions_T4', 'CNN_no_wrong_pred_T4'])

plot_metrics(load_results(path, 'CNN_no_result_T4'))

output.eval_js('new Audio("https://upload.wikimedia.org/wikipedia/commons/0/05/Beep-09.ogg").play()')
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
#  20%|██        | 1/5 [00:32<02:11, 32.75s/it]
# Epoch: [1/5]
# Train loss is: 0.023840573051162835
# Validation loss is: 0.027100316909252856
# Train accuracy is: 68.21 %
# Train accuracy for pixels is: 99.76308532596191 %
# Validation accuracy is: 63.0 %
# Validation accuracy for pixels is: 99.7334928750136 %
#  40%|████      | 2/5 [01:05<01:38, 32.81s/it]
# Epoch: [2/5]
# Train loss is: 0.022934692648110034
# Validation loss is: 0.025105032824587318
# Train accuracy is: 72.95 %
# Train accuracy for pixels is: 99.80493302700594 %
# Validation accuracy is: 74.0 %
# Validation accuracy for pixels is: 99.80419884694876 %
#  60%|██████    | 3/5 [01:38<01:05, 32.76s/it]
# Epoch: [3/5]
# Train loss is: 0.019705809341525476
# Validation loss is: 0.02193861129166643
# Train accuracy is: 75.67 %
# Train accuracy for pixels is: 99.8297193147425 %
# Validation accuracy is: 75.0 %
# Validation accuracy for pixels is: 99.82595453062112 %
#  80%|████████  | 4/5 [02:11<00:32, 32.76s/it]
# Epoch: [4/5]
# Train loss is: 0.02271720020623904
# Validation loss is: 0.024640269416477404
# Train accuracy is: 73.49 %
# Train accuracy for pixels is: 99.80921227399185 %
# Validation accuracy is: 71.0 %
# Validation accuracy for pixels is: 99.81507668878494 %
# 100%|██████████| 5/5 [02:43<00:00, 32.76s/it]
# Epoch: [5/5]
# Train loss is: 0.02320556554478603
# Validation loss is: 0.0245951419263806
# Train accuracy is: 72.76 %
# Train accuracy for pixels is: 99.8047663030974 %
# Validation accuracy is: 71.0 %
# Validation accuracy for pixels is: 99.80419884694876 %
# /usr/local/lib/python3.6/dist-packages/torch/storage.py:34: FutureWarning: pickle support for Storage will be removed in 1.5. Use `torch.save` instead
#   warnings.warn("pickle support for Storage will be removed in 1.5. Use `torch.save` instead", FutureWarning)

# %%
compare_plots(load_results(path, 'CNN_no_wrong_pred_T4'), n=5) # 5 wrong predictions

# %%
CNN_result_T4, CNN_predictions_T4, CNN_wrong_pred_T4 = evaluate_metrics(TaskSolver(), 
                                                                            data, 
                                                                            CNN_big, CrossEntropyLoss, 
                                                                            attention = 'yes',
                                                                            n_epoch=5, device=device,
                                                                            lr = 0.1, verbose=True)

save_results(path, [CNN_result_T4, CNN_predictions_T4, CNN_wrong_pred_T4], 
             ['CNN_result_T4', 'CNN_predictions_T4', 'CNN_wrong_pred_T4'])


plot_metrics(load_results(path,'CNN_result_T4'))
# Out:
#  20%|████████████████▊                                                                   | 1/5 [00:55<03:41, 55.28s/it]
# Epoch: [1/5]
# Train loss is: 18.73783975153361
# Validation loss is: 10.750450037419796
# Train accuracy is: 67.02 %
# Train accuracy for pixels is: 99.75166042291228 %
# Validation accuracy is: 74.0 %
# Validation accuracy for pixels is: 99.83631540328498 %
#  40%|█████████████████████████████████▌                                                  | 2/5 [01:50<02:46, 55.39s/it]
# Epoch: [2/5]
# Train loss is: 21.05780090933765
# Validation loss is: 14.970262279510498
# Train accuracy is: 69.16 %
# Train accuracy for pixels is: 99.77460120895715 %
# Validation accuracy is: 75.0 %
# Validation accuracy for pixels is: 99.81373821753118 %
#  60%|██████████████████████████████████████████████████▍                                 | 3/5 [02:45<01:50, 55.16s/it]
# Epoch: [3/5]
# Train loss is: 16.9385629297134
# Validation loss is: 12.426803271770478
# Train accuracy is: 75.43 %
# Train accuracy for pixels is: 99.82811114922202 %
# Validation accuracy is: 78.0 %
# Validation accuracy for pixels is: 99.87018118191567 %
#  80%|███████████████████████████████████████████████████████████████████▏                | 4/5 [03:46<00:56, 56.86s/it]
# Epoch: [4/5]
# Train loss is: 20.025267307388575
# Validation loss is: 15.411570969820023
# Train accuracy is: 71.54 %
# Train accuracy for pixels is: 99.79570450485765 %
# Validation accuracy is: 73.0 %
# Validation accuracy for pixels is: 99.80244962465429 %
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [04:44<00:00, 56.91s/it]
# Epoch: [5/5]
# Train loss is: 16.167497236827696
# Validation loss is: 16.722037644684313
# Train accuracy is: 74.99 %
# Train accuracy for pixels is: 99.82677479275338 %
# Validation accuracy is: 74.0 %
# Validation accuracy for pixels is: 99.80809392109273 %
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-75-abd1e28d8fe8> in <module>
#       6                                                                             lr = 0.1, verbose=True)
#       7
# ----> 8 save_results(path, [CNN_result_T4, CNN_predictions_T4, CNN_wrong_pred_T4],
#       9              ['CNN_result_T4', 'CNN_predictions_T4', 'CNN_wrong_pred_T4'])
#      10
#
# NameError: name 'CNN_result_T4' is not defined

# %%
plot_metrics(load_results(path,'CNN_result_T4'))

# %% [markdown]
# # Task 5

# %%
task=task_builder(gener_five, 5, 2)
plot_task(task)
# input.shape == output.shape and inputs have same shape between each others

# %%
data=[task_builder(gener_five, 10000, 100)]

# %%
# Training
FullyCon_result_T5, FullyCon_predictions_T5, FullyCon_wrong_pred_T5 = evaluate_metrics(TaskSolver(), 
                                                                                        data, 
                                                                                        FullyCon_T4, CrossEntropyLoss, 
                                                                                        n_epoch=5, device=device,
                                                                                        lr = 0.1, verbose=True)

save_results(path, [FullyCon_result_T5, FullyCon_predictions_T5, FullyCon_wrong_pred_T5 ], 
             ['FullyCon_result_T5', 'FullyCon_predictions_T5', 'FullyCon_wrong_pred_T5' ])


plot_metrics(load_results(path, 'FullyCon_result_T5'))
# Out:
#  20%|████████████████▊                                                                   | 1/5 [00:56<03:45, 56.31s/it]
# Epoch: [1/5]
# Train loss is: 3.9966718079977874
# Validation loss is: 5.9465218271687625
# Train accuracy is: 2.0 %
# Train accuracy for pixels is: 79.39298947601165 %
# Validation accuracy is: 0.0 %
# Validation accuracy for pixels is: 74.46413502109705 %
#  40%|█████████████████████████████████▌                                                  | 2/5 [01:51<02:48, 56.01s/it]
# Epoch: [2/5]
# Train loss is: 3.4779995691636474
# Validation loss is: 6.000900580054149
# Train accuracy is: 4.22 %
# Train accuracy for pixels is: 83.45084109883135 %
# Validation accuracy is: 1.0 %
# Validation accuracy for pixels is: 77.36708860759494 %
#  60%|██████████████████████████████████████████████████▍                                 | 3/5 [02:47<01:51, 55.91s/it]
# Epoch: [3/5]
# Train loss is: 3.1793372561835804
# Validation loss is: 6.018693253219135
# Train accuracy is: 5.44 %
# Train accuracy for pixels is: 85.2396694804338 %
# Validation accuracy is: 4.0 %
# Validation accuracy for pixels is: 78.9873417721519 %
#  80%|███████████████████████████████████████████████████████████████████▏                | 4/5 [03:43<00:55, 55.96s/it]
# Epoch: [4/5]
# Train loss is: 3.040562001596285
# Validation loss is: 6.26578983458673
# Train accuracy is: 5.2 %
# Train accuracy for pixels is: 86.36892088999204 %
# Validation accuracy is: 6.0 %
# Validation accuracy for pixels is: 80.0675105485232 %
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [04:41<00:00, 56.20s/it]
# Epoch: [5/5]
# Train loss is: 2.7877428470382934
# Validation loss is: 6.194876785062848
# Train accuracy is: 6.16 %
# Train accuracy for pixels is: 87.7533371135528 %
# Validation accuracy is: 3.0 %
# Validation accuracy for pixels is: 80.82700421940929 %

# %%
compare_plots(load_results(path, 'FullyCon_wrong_pred_T5'), n=5) # 5 wrong predictions

# %%
CNN_result_T5, CNN_predictions_T5, CNN_wrong_pred_T5 = evaluate_metrics(TaskSolver(), 
                                                                            data, 
                                                                            CNN_big, CrossEntropyLoss, 
                                                                            attention = 'yes',
                                                                            n_epoch=5, device=device,
                                                                            lr = 0.1, verbose=True)

save_results(path, [CNN_result_T5, CNN_predictions_T5, CNN_wrong_pred_T5], 
             ['CNN_result_T5', 'CNN_predictions_T5', 'CNN_wrong_pred_T5'])


plot_metrics(load_results(path,'CNN_result_T5'))
# Out:
#  20%|████████████████▊                                                                   | 1/5 [00:54<03:39, 54.87s/it]
# Epoch: [1/5]
# Train loss is: 288.0644925853968
# Validation loss is: 288.59338835172355
# Train accuracy is: 5.52 %
# Train accuracy for pixels is: 81.19073346956388 %
# Validation accuracy is: 7.0 %
# Validation accuracy for pixels is: 81.0126582278481 %
#  40%|█████████████████████████████████▌                                                  | 2/5 [01:51<02:46, 55.50s/it]
# Epoch: [2/5]
# Train loss is: 292.81286737780346
# Validation loss is: 298.98844536365783
# Train accuracy is: 5.89 %
# Train accuracy for pixels is: 82.12598116309508 %
# Validation accuracy is: 8.0 %
# Validation accuracy for pixels is: 81.11392405063292 %
#  60%|██████████████████████████████████████████████████▍                                 | 3/5 [02:50<01:53, 56.55s/it]
# Epoch: [3/5]
# Train loss is: 394.7211037000589
# Validation loss is: 388.4809811210632
# Train accuracy is: 5.4 %
# Train accuracy for pixels is: 80.20127885537808 %
# Validation accuracy is: 6.0 %
# Validation accuracy for pixels is: 78.9367088607595 %
#  80%|███████████████████████████████████████████████████████████████████▏                | 4/5 [03:48<00:56, 56.90s/it]
# Epoch: [4/5]
# Train loss is: 485.82224057376385
# Validation loss is: 492.1422131940583
# Train accuracy is: 7.56 %
# Train accuracy for pixels is: 81.02401152610312 %
# Validation accuracy is: 9.0 %
# Validation accuracy for pixels is: 80.0168776371308 %
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [04:45<00:00, 57.09s/it]
# Epoch: [5/5]
# Train loss is: 283.4556461668949
# Validation loss is: 289.0209917390346
# Train accuracy is: 5.85 %
# Train accuracy for pixels is: 82.43249990192827 %
# Validation accuracy is: 6.0 %
# Validation accuracy for pixels is: 82.39662447257383 %

# %%
compare_plots(load_results(path, 'CNN_wrong_pred_T5'), n=5) # 5 wrong predictions

# %%
# Training with attention
LSTM_result_T5, LSTM_predictions_T5, LSTM_wrong_pred_T5 = evaluate_metrics(TaskSolver(), 
                                                                            data, 
                                                                            LSTM_T4, CrossEntropyLoss, 
                                                                            attention = 'yes',
                                                                            n_epoch=5, device=device,
                                                                            lr = 0.1, verbose=True)

save_results(path, [LSTM_result_T5, LSTM_predictions_T5, LSTM_wrong_pred_T5], 
             ['LSTM_result_T5', 'LSTM_predictions_T5', 'LSTM_wrong_pred_T5'])


plot_metrics(load_results(path, 'LSTM_result_T5'))
# Out:
#  20%|████████████████▊                                                                   | 1/5 [01:11<04:45, 71.40s/it]
# Epoch: [1/5]
# Train loss is: 1.879225599372387
# Validation loss is: 1.8849334692955018
# Train accuracy is: 0.0 %
# Train accuracy for pixels is: 54.321575424293975 %
# Validation accuracy is: 0.0 %
# Validation accuracy for pixels is: 53.08016877637131 %
#  40%|█████████████████████████████████▌                                                  | 2/5 [02:19<03:31, 70.40s/it]
# Epoch: [2/5]
# Train loss is: 1.8579171886920929
# Validation loss is: 1.8621657490730286
# Train accuracy is: 0.0 %
# Train accuracy for pixels is: 56.6576440673735 %
# Validation accuracy is: 0.0 %
# Validation accuracy for pixels is: 55.949367088607595 %
#  60%|██████████████████████████████████████████████████▍                                 | 3/5 [03:29<02:20, 70.27s/it]
# Epoch: [3/5]
# Train loss is: 1.857041249215603
# Validation loss is: 1.8608482849597932
# Train accuracy is: 0.0 %
# Train accuracy for pixels is: 56.86805250938814 %
# Validation accuracy is: 0.0 %
# Validation accuracy for pixels is: 56.13502109704641 %
#  80%|███████████████████████████████████████████████████████████████████▏                | 4/5 [04:37<01:09, 69.50s/it]
# Epoch: [4/5]
# Train loss is: 1.8557236295580863
# Validation loss is: 1.8588658273220062
# Train accuracy is: 0.0 %
# Train accuracy for pixels is: 56.638564657800984 %
# Validation accuracy is: 0.0 %
# Validation accuracy for pixels is: 55.81434599156118 %
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [05:46<00:00, 69.38s/it]
# Epoch: [5/5]
# Train loss is: 1.8557236293077468
# Validation loss is: 1.8588658273220062
# Train accuracy is: 0.0 %
# Train accuracy for pixels is: 56.63892128227897 %
# Validation accuracy is: 0.0 %
# Validation accuracy for pixels is: 55.81434599156118 %

# %%
compare_plots(load_results(path, 'LSTM_wrong_pred_T5'), n=5) # 5 wrong predictions
